# %% [markdown]
# In this notebook we evaluate the performance of the model, both overall and in subslices of

# %%
import pandas as pd
import joblib
import os

from pathlib import Path

# %%
path = Path(os.getcwd())
dirname = os.path.join(path.parent.absolute(), 'model', 'latest')
data_path = os.path.join(path.parent.absolute(), 'data', 'census.csv')

# %%
    # Add code to load in the data.
model = joblib.load(os.path.join(dirname, 'model'))
encoder = joblib.load(os.path.join(dirname, 'encoder'))
lb = joblib.load(os.path.join(dirname, 'lb'))
cat_features = joblib.load(os.path.join(dirname, 'cat_features'))

# %%
import sys
sys.path.append("../") # go to parent dir

# %%
from ml.data import process_data
from ml.model import inference, compute_model_metrics
from sklearn.metrics import confusion_matrix
from ml.eval import get_tn_fp_fn_tp

# %%
data = pd.read_csv(data_path)
X, y, _, _ =  process_data(
        data, categorical_features=cat_features, label="salary", encoder = encoder, lb = lb, training = False
)

# %% [markdown]
# ### At first an overall breakdown of metrics is shown

# %%
preds = inference(model, X)
precision, recall, fbeta = compute_model_metrics(y, preds)
print(f"precision: {precision}, recall: {recall}, fbeta: {fbeta}")
tn, fp, fn, tp = get_tn_fp_fn_tp(y, preds)
print(f"TN, FP, FN, TP: {(tn, fp, fn, tp)}")
# Out:
# precision: 0.8031866464339908, recall: 0.6750414487947966, fbeta: 0.7335596978726352
# TN, FP, FN, TP: (23423, 1297, 2548, 5293)

# %% [markdown]
# The model sees the value `<=50K` as negative and `>50K` as positive.
# There are in the database 24720 that earn `<=50k` (negative) and 7841 that earn `>50K`.
# There are more False Negatives than False Positives, and precision is better then recall.
#
#
#
# Taking into account that
# * a True Negative is when we correctly recognize that someone earns less than 50k,
# * a False Positive when someone earns less than 50k, but we predict that it earns more than 50k
# * a False Negative when someone earns more than 50k, but we predict that they earn less than 50k
# * a True Positive when we correctly recognize that someone earns more than 50k
#
#
# We have a relatively high number of False Negatives overall, which means that we often predict that someone is making less money than the case is,
# rather than the other case.
# That is the reason we have a low recall : TP/(TP+FN) and a higher precision TP/(TP+FP)

# %%
for slice_feature in cat_features:
    list_unique = data[slice_feature].unique()
    print(f"{slice_feature} : {list_unique}")
# Out:
# workclass : ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# education : ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# marital-status : ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# occupation : ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# relationship : ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
# race : ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# sex : ['Male' 'Female']
# native-country : ['United-States' 'Cuba' 'Jamaica' 'India' '?' 'Mexico' 'South'
#  'Puerto-Rico' 'Honduras' 'England' 'Canada' 'Germany' 'Iran'
#  'Philippines' 'Italy' 'Poland' 'Columbia' 'Cambodia' 'Thailand' 'Ecuador'
#  'Laos' 'Taiwan' 'Haiti' 'Portugal' 'Dominican-Republic' 'El-Salvador'
#  'France' 'Guatemala' 'China' 'Japan' 'Yugoslavia' 'Peru'
#  'Outlying-US(Guam-USVI-etc)' 'Scotland' 'Trinadad&Tobago' 'Greece'
#  'Nicaragua' 'Vietnam' 'Hong' 'Ireland' 'Hungary' 'Holand-Netherlands']

# %% [markdown]
# These are the way the dataset can be sliced over unique features, now we can verify how the model treats diffent slices of the dataset.

# %%
 for slice_feature in cat_features:
     print(f"==== SLICE FORF FEATURE : {slice_feature}")
     for cls in data[slice_feature].unique():
         print(f"== CLS FOR FEATURE : {cls}")
         idx_slice = data[slice_feature] == cls
         x_slice, y_slice, preds_slice = X[idx_slice], y[idx_slice], preds[idx_slice]

         precision, recall, fbeta = compute_model_metrics(y_slice, preds_slice)
         print(f"precision: {precision}, recall: {recall}, fbeta: {fbeta}")
         if y_slice is not None and preds_slice is not None:
             slice_result = get_tn_fp_fn_tp(y_slice, preds_slice)
             if slice_result:
                 tn, fp, fn, tp = slice_result
                 print(f"TN, FP, FN, TP: {(tn, fp, fn, tp)}")
# Out:
# ==== SLICE FORF FEATURE : workclass
# == CLS FOR FEATURE : State-gov
# precision: 0.798219584569733, recall: 0.7620396600566572, fbeta: 0.7797101449275363
# TN, FP, FN, TP: (877, 68, 84, 269)
# == CLS FOR FEATURE : Self-emp-not-inc
# precision: 0.8072519083969466, recall: 0.5842541436464088, fbeta: 0.6778846153846154
# TN, FP, FN, TP: (1716, 101, 301, 423)
# == CLS FOR FEATURE : Private
# precision: 0.8042935596605092, recall: 0.6492041104170865, fbeta: 0.7184747463485338
# TN, FP, FN, TP: (16949, 784, 1741, 3222)
# == CLS FOR FEATURE : Federal-gov
# precision: 0.8093922651933702, recall: 0.7897574123989218, fbeta: 0.7994542974079126
# TN, FP, FN, TP: (520, 69, 78, 293)
# == CLS FOR FEATURE : Local-gov
# precision: 0.7851099830795262, recall: 0.7520259319286872, fbeta: 0.7682119205298013
# TN, FP, FN, TP: (1349, 127, 153, 464)
# == CLS FOR FEATURE : ?
# precision: 0.7461538461538462, recall: 0.5078534031413613, fbeta: 0.6043613707165109
# TN, FP, FN, TP: (1612, 33, 94, 97)
# == CLS FOR FEATURE : Self-emp-inc
# precision: 0.8203125, recall: 0.8440514469453376, fbeta: 0.8320126782884311
# TN, FP, FN, TP: (379, 115, 97, 525)
# == CLS FOR FEATURE : Without-pay
# precision: 1.0, recall: 1.0, fbeta: 1.0
# == CLS FOR FEATURE : Never-worked
# precision: 1.0, recall: 1.0, fbeta: 1.0
# ==== SLICE FORF FEATURE : education
# == CLS FOR FEATURE : Bachelors
# precision: 0.7830974188176519, recall: 0.8469158036920306, fbeta: 0.8137573004542504
# TN, FP, FN, TP: (2613, 521, 340, 1881)
# == CLS FOR FEATURE : HS-grad
# precision: 0.847887323943662, recall: 0.35940298507462687, fbeta: 0.5048218029350104
# TN, FP, FN, TP: (8718, 108, 1073, 602)
# == CLS FOR FEATURE : 11th
# precision: 1.0, recall: 0.35, fbeta: 0.5185185185185185
# TN, FP, FN, TP: (1115, 0, 39, 21)
# == CLS FOR FEATURE : Masters
# precision: 0.827485380116959, recall: 0.8852971845672576, fbeta: 0.8554156171284635
# TN, FP, FN, TP: (587, 177, 110, 849)
# == CLS FOR FEATURE : 9th
# precision: 1.0, recall: 0.1111111111111111, fbeta: 0.19999999999999998
# TN, FP, FN, TP: (487, 0, 24, 3)
# == CLS FOR FEATURE : Some-college
# precision: 0.7387791741472173, recall: 0.5933669790915646, fbeta: 0.6581367453018793
# TN, FP, FN, TP: (5613, 291, 564, 823)
# == CLS FOR FEATURE : Assoc-acdm
# precision: 0.7848101265822784, recall: 0.7018867924528301, fbeta: 0.7410358565737051
# TN, FP, FN, TP: (751, 51, 79, 186)
# == CLS FOR FEATURE : Assoc-voc
# precision: 0.7962962962962963, recall: 0.5955678670360111, fbeta: 0.6814580031695722
# TN, FP, FN, TP: (966, 55, 146, 215)
# == CLS FOR FEATURE : 7th-8th
# precision: 0.875, recall: 0.175, fbeta: 0.29166666666666663
# TN, FP, FN, TP: (605, 1, 33, 7)
# == CLS FOR FEATURE : Doctorate
# precision: 0.8598130841121495, recall: 0.9019607843137255, fbeta: 0.8803827751196173
# TN, FP, FN, TP: (62, 45, 30, 276)
# == CLS FOR FEATURE : Prof-school
# precision: 0.8946188340807175, recall: 0.9432624113475178, fbeta: 0.9182968929804373
# TN, FP, FN, TP: (106, 47, 24, 399)
# == CLS FOR FEATURE : 5th-6th
# precision: 1.0, recall: 0.3125, fbeta: 0.47619047619047616
# TN, FP, FN, TP: (317, 0, 11, 5)
# == CLS FOR FEATURE : 10th
# precision: 1.0, recall: 0.25806451612903225, fbeta: 0.41025641025641024
# TN, FP, FN, TP: (871, 0, 46, 16)
# == CLS FOR FEATURE : 1st-4th
# precision: 1.0, recall: 0.16666666666666666, fbeta: 0.2857142857142857
# TN, FP, FN, TP: (162, 0, 5, 1)
# == CLS FOR FEATURE : Preschool
# precision: 0.0, recall: 1.0, fbeta: 0.0
# TN, FP, FN, TP: (50, 1, 0, 0)
# == CLS FOR FEATURE : 12th
# precision: 1.0, recall: 0.2727272727272727, fbeta: 0.42857142857142855
# TN, FP, FN, TP: (400, 0, 24, 9)
# ==== SLICE FORF FEATURE : marital-status
# == CLS FOR FEATURE : Never-married
# precision: 0.9513274336283186, recall: 0.4378818737270876, fbeta: 0.599721059972106
# TN, FP, FN, TP: (10181, 11, 276, 215)
# == CLS FOR FEATURE : Married-civ-spouse
# precision: 0.792938459000165, recall: 0.7181709503885236, fbeta: 0.7537050105857446
# TN, FP, FN, TP: (7029, 1255, 1886, 4806)
# == CLS FOR FEATURE : Divorced
# precision: 0.8744186046511628, recall: 0.4060475161987041, fbeta: 0.5545722713864307
# TN, FP, FN, TP: (3953, 27, 275, 188)
# == CLS FOR FEATURE : Married-spouse-absent
# precision: 0.8823529411764706, recall: 0.4411764705882353, fbeta: 0.5882352941176471
# TN, FP, FN, TP: (382, 2, 19, 15)
# == CLS FOR FEATURE : Separated
# precision: 0.96875, recall: 0.4696969696969697, fbeta: 0.6326530612244898
# TN, FP, FN, TP: (958, 1, 35, 31)
# == CLS FOR FEATURE : Married-AF-spouse
# precision: 1.0, recall: 0.3, fbeta: 0.4615384615384615
# TN, FP, FN, TP: (13, 0, 7, 3)
# == CLS FOR FEATURE : Widowed
# precision: 0.9722222222222222, recall: 0.4117647058823529, fbeta: 0.5785123966942148
# TN, FP, FN, TP: (907, 1, 50, 35)
# ==== SLICE FORF FEATURE : occupation
# == CLS FOR FEATURE : Adm-clerical
# precision: 0.7670157068062827, recall: 0.5779092702169625, fbeta: 0.6591676040494938
# TN, FP, FN, TP: (3174, 89, 214, 293)
# == CLS FOR FEATURE : Exec-managerial
# precision: 0.817503729487817, recall: 0.8353658536585366, fbeta: 0.8263382759487309
# TN, FP, FN, TP: (1731, 367, 324, 1644)
# == CLS FOR FEATURE : Handlers-cleaners
# precision: 0.9166666666666666, recall: 0.2558139534883721, fbeta: 0.4
# TN, FP, FN, TP: (1282, 2, 64, 22)
# == CLS FOR FEATURE : Prof-specialty
# precision: 0.8093285494618144, recall: 0.8493813878429263, fbeta: 0.8288713910761155
# TN, FP, FN, TP: (1909, 372, 280, 1579)
# == CLS FOR FEATURE : Other-service
# precision: 0.9, recall: 0.19708029197080293, fbeta: 0.3233532934131737
# TN, FP, FN, TP: (3155, 3, 110, 27)
# == CLS FOR FEATURE : Sales
# precision: 0.7713625866050808, recall: 0.6795523906408952, fbeta: 0.7225527312060572
# TN, FP, FN, TP: (2469, 198, 315, 668)
# == CLS FOR FEATURE : Craft-repair
# precision: 0.7823408624229979, recall: 0.4101184068891281, fbeta: 0.5381355932203389
# TN, FP, FN, TP: (3064, 106, 548, 381)
# == CLS FOR FEATURE : Transport-moving
# precision: 0.8027210884353742, recall: 0.36875, fbeta: 0.505353319057816
# TN, FP, FN, TP: (1248, 29, 202, 118)
# == CLS FOR FEATURE : Farming-fishing
# precision: 0.9069767441860465, recall: 0.3391304347826087, fbeta: 0.4936708860759494
# TN, FP, FN, TP: (875, 4, 76, 39)
# == CLS FOR FEATURE : Machine-op-inspct
# precision: 0.922077922077922, recall: 0.284, fbeta: 0.43425076452599387
# TN, FP, FN, TP: (1746, 6, 179, 71)
# == CLS FOR FEATURE : Tech-support
# precision: 0.7910447761194029, recall: 0.7491166077738516, fbeta: 0.7695099818511798
# TN, FP, FN, TP: (589, 56, 71, 212)
# == CLS FOR FEATURE : ?
# precision: 0.7461538461538462, recall: 0.5078534031413613, fbeta: 0.6043613707165109
# TN, FP, FN, TP: (1619, 33, 94, 97)
# == CLS FOR FEATURE : Protective-serv
# precision: 0.813953488372093, recall: 0.6635071090047393, fbeta: 0.731070496083551
# TN, FP, FN, TP: (406, 32, 71, 140)
# == CLS FOR FEATURE : Armed-Forces
# precision: 1.0, recall: 1.0, fbeta: 1.0
# TN, FP, FN, TP: (8, 0, 0, 1)
# == CLS FOR FEATURE : Priv-house-serv
# precision: 1.0, recall: 1.0, fbeta: 1.0
# TN, FP, FN, TP: (148, 0, 0, 1)
# ==== SLICE FORF FEATURE : relationship
# == CLS FOR FEATURE : Not-in-family
# precision: 0.9146341463414634, recall: 0.4380841121495327, fbeta: 0.5924170616113744
# TN, FP, FN, TP: (7414, 35, 481, 375)
# == CLS FOR FEATURE : Husband
# precision: 0.7947516401124649, recall: 0.7164582629266644, fbeta: 0.7535768239580557
# TN, FP, FN, TP: (6180, 1095, 1678, 4240)
# == CLS FOR FEATURE : Wife
# precision: 0.7830985915492957, recall: 0.7463087248322148, fbeta: 0.7642611683848798
# TN, FP, FN, TP: (669, 154, 189, 556)
# == CLS FOR FEATURE : Own-child
# precision: 0.9545454545454546, recall: 0.31343283582089554, fbeta: 0.4719101123595506
# TN, FP, FN, TP: (5000, 1, 46, 21)
# == CLS FOR FEATURE : Unmarried
# precision: 0.9130434782608695, recall: 0.3853211009174312, fbeta: 0.5419354838709678
# TN, FP, FN, TP: (3220, 8, 134, 84)
# == CLS FOR FEATURE : Other-relative
# precision: 0.8095238095238095, recall: 0.4594594594594595, fbeta: 0.5862068965517242
# TN, FP, FN, TP: (940, 4, 20, 17)
# ==== SLICE FORF FEATURE : race
# == CLS FOR FEATURE : White
# precision: 0.8037880046519356, recall: 0.6797808065196009, fbeta: 0.7366017052375152
# TN, FP, FN, TP: (19518, 1181, 2279, 4838)
# == CLS FOR FEATURE : Black
# precision: 0.823943661971831, recall: 0.6046511627906976, fbeta: 0.6974664679582713
# TN, FP, FN, TP: (2687, 50, 153, 234)
# == CLS FOR FEATURE : Asian-Pac-Islander
# precision: 0.7651821862348178, recall: 0.6847826086956522, fbeta: 0.722753346080306
# TN, FP, FN, TP: (705, 58, 87, 189)
# == CLS FOR FEATURE : Amer-Indian-Eskimo
# precision: 0.8260869565217391, recall: 0.5277777777777778, fbeta: 0.6440677966101694
# TN, FP, FN, TP: (271, 4, 17, 19)
# == CLS FOR FEATURE : Other
# precision: 0.7647058823529411, recall: 0.52, fbeta: 0.6190476190476191
# TN, FP, FN, TP: (242, 4, 12, 13)
# ==== SLICE FORF FEATURE : sex
# == CLS FOR FEATURE : Male
# precision: 0.8010186160871092, recall: 0.6846292404683278, fbeta: 0.738264810618323
# TN, FP, FN, TP: (13995, 1133, 2101, 4561)
# == CLS FOR FEATURE : Female
# precision: 0.8169642857142857, recall: 0.6208651399491094, fbeta: 0.7055421686746988
# TN, FP, FN, TP: (9428, 164, 447, 732)
# ==== SLICE FORF FEATURE : native-country
# == CLS FOR FEATURE : United-States
# precision: 0.8039574326571334, recall: 0.6742434806860967, fbeta: 0.7334091770951839
# TN, FP, FN, TP: (20820, 1179, 2336, 4835)
# == CLS FOR FEATURE : Cuba
# precision: 0.9411764705882353, recall: 0.64, fbeta: 0.7619047619047621
# TN, FP, FN, TP: (69, 1, 9, 16)
# == CLS FOR FEATURE : Jamaica
# precision: 0.5, recall: 0.3, fbeta: 0.37499999999999994
# TN, FP, FN, TP: (68, 3, 7, 3)
# == CLS FOR FEATURE : India
# precision: 0.75, recall: 0.825, fbeta: 0.7857142857142856
# TN, FP, FN, TP: (49, 11, 7, 33)
# == CLS FOR FEATURE : ?
# precision: 0.796875, recall: 0.6986301369863014, fbeta: 0.7445255474452555
# TN, FP, FN, TP: (411, 26, 44, 102)
# == CLS FOR FEATURE : Mexico
# precision: 0.9230769230769231, recall: 0.36363636363636365, fbeta: 0.5217391304347827
# TN, FP, FN, TP: (609, 1, 21, 12)
# == CLS FOR FEATURE : South
# precision: 0.6111111111111112, recall: 0.6875, fbeta: 0.6470588235294118
# TN, FP, FN, TP: (57, 7, 5, 11)
# == CLS FOR FEATURE : Puerto-Rico
# precision: 0.7142857142857143, recall: 0.8333333333333334, fbeta: 0.7692307692307692
# TN, FP, FN, TP: (98, 4, 2, 10)
# == CLS FOR FEATURE : Honduras
# precision: 1.0, recall: 1.0, fbeta: 1.0
# TN, FP, FN, TP: (12, 0, 0, 1)
# == CLS FOR FEATURE : England
# precision: 0.8260869565217391, recall: 0.6333333333333333, fbeta: 0.7169811320754716
# TN, FP, FN, TP: (56, 4, 11, 19)
# == CLS FOR FEATURE : Canada
# precision: 0.8, recall: 0.717948717948718, fbeta: 0.7567567567567569
# TN, FP, FN, TP: (75, 7, 11, 28)
# == CLS FOR FEATURE : Germany
# precision: 0.8823529411764706, recall: 0.6818181818181818, fbeta: 0.7692307692307693
# TN, FP, FN, TP: (89, 4, 14, 30)
# == CLS FOR FEATURE : Iran
# precision: 0.7894736842105263, recall: 0.8333333333333334, fbeta: 0.8108108108108109
# TN, FP, FN, TP: (21, 4, 3, 15)
# == CLS FOR FEATURE : Philippines
# precision: 0.8269230769230769, recall: 0.7049180327868853, fbeta: 0.7610619469026548
# TN, FP, FN, TP: (128, 9, 18, 43)
# == CLS FOR FEATURE : Italy
# precision: 0.8888888888888888, recall: 0.64, fbeta: 0.7441860465116279
# TN, FP, FN, TP: (46, 2, 9, 16)
# == CLS FOR FEATURE : Poland
# precision: 0.75, recall: 0.5, fbeta: 0.6
# TN, FP, FN, TP: (46, 2, 6, 6)
# == CLS FOR FEATURE : Columbia
# precision: 0.5, recall: 1.0, fbeta: 0.6666666666666666
# TN, FP, FN, TP: (55, 2, 0, 2)
# == CLS FOR FEATURE : Cambodia
# precision: 1.0, recall: 0.14285714285714285, fbeta: 0.25
# TN, FP, FN, TP: (12, 0, 6, 1)
# == CLS FOR FEATURE : Thailand
# precision: 1.0, recall: 1.0, fbeta: 1.0
# TN, FP, FN, TP: (15, 0, 0, 3)
# == CLS FOR FEATURE : Ecuador
# precision: 0.5, recall: 0.5, fbeta: 0.5
# TN, FP, FN, TP: (22, 2, 2, 2)
# == CLS FOR FEATURE : Laos
# precision: 0.5, recall: 0.5, fbeta: 0.5
# TN, FP, FN, TP: (15, 1, 1, 1)
# == CLS FOR FEATURE : Taiwan
# precision: 0.8, recall: 0.8, fbeta: 0.8000000000000002
# TN, FP, FN, TP: (27, 4, 4, 16)
# == CLS FOR FEATURE : Haiti
# precision: 1.0, recall: 0.5, fbeta: 0.6666666666666666
# TN, FP, FN, TP: (40, 0, 2, 2)
# == CLS FOR FEATURE : Portugal
# precision: 1.0, recall: 0.5, fbeta: 0.6666666666666666
# TN, FP, FN, TP: (33, 0, 2, 2)
# == CLS FOR FEATURE : Dominican-Republic
# precision: 0.5, recall: 0.5, fbeta: 0.5
# TN, FP, FN, TP: (67, 1, 1, 1)
# == CLS FOR FEATURE : El-Salvador
# precision: 1.0, recall: 0.8888888888888888, fbeta: 0.9411764705882353
# TN, FP, FN, TP: (97, 0, 1, 8)
# == CLS FOR FEATURE : France
# precision: 0.8461538461538461, recall: 0.9166666666666666, fbeta: 0.8799999999999999
# TN, FP, FN, TP: (15, 2, 1, 11)
# == CLS FOR FEATURE : Guatemala
# precision: 0.5, recall: 0.3333333333333333, fbeta: 0.4
# TN, FP, FN, TP: (60, 1, 2, 1)
# == CLS FOR FEATURE : China
# precision: 0.72, recall: 0.9, fbeta: 0.7999999999999999
# TN, FP, FN, TP: (48, 7, 2, 18)
# == CLS FOR FEATURE : Japan
# precision: 0.7727272727272727, recall: 0.7083333333333334, fbeta: 0.7391304347826088
# TN, FP, FN, TP: (33, 5, 7, 17)
# == CLS FOR FEATURE : Yugoslavia
# precision: 0.6, recall: 0.5, fbeta: 0.5454545454545454
# TN, FP, FN, TP: (8, 2, 3, 3)
# == CLS FOR FEATURE : Peru
# precision: 1.0, recall: 0.5, fbeta: 0.6666666666666666
# TN, FP, FN, TP: (29, 0, 1, 1)
# == CLS FOR FEATURE : Outlying-US(Guam-USVI-etc)
# precision: 1.0, recall: 1.0, fbeta: 1.0
# == CLS FOR FEATURE : Scotland
# precision: 1.0, recall: 1.0, fbeta: 1.0
# TN, FP, FN, TP: (9, 0, 0, 3)
# == CLS FOR FEATURE : Trinadad&Tobago
# precision: 0.5, recall: 0.5, fbeta: 0.5
# TN, FP, FN, TP: (16, 1, 1, 1)
# == CLS FOR FEATURE : Greece
# precision: 0.7777777777777778, recall: 0.875, fbeta: 0.823529411764706
# TN, FP, FN, TP: (19, 2, 1, 7)
# == CLS FOR FEATURE : Nicaragua
# precision: 0.5, recall: 0.5, fbeta: 0.5
# TN, FP, FN, TP: (31, 1, 1, 1)
# == CLS FOR FEATURE : Vietnam
# precision: 0.6666666666666666, recall: 0.4, fbeta: 0.5
# TN, FP, FN, TP: (61, 1, 3, 2)
# == CLS FOR FEATURE : Hong
# precision: 0.8333333333333334, recall: 0.8333333333333334, fbeta: 0.8333333333333334
# TN, FP, FN, TP: (13, 1, 1, 5)
# == CLS FOR FEATURE : Ireland
# precision: 1.0, recall: 0.6, fbeta: 0.7499999999999999
# TN, FP, FN, TP: (19, 0, 2, 3)
# == CLS FOR FEATURE : Hungary
# precision: 1.0, recall: 0.6666666666666666, fbeta: 0.8
# TN, FP, FN, TP: (10, 0, 1, 2)
# == CLS FOR FEATURE : Holand-Netherlands
# precision: 1.0, recall: 1.0, fbeta: 1.0

# %% [markdown]
# We have printed out precision and recall for this model over different slices of the dataset, some conclusions can be drawn.

# %% [markdown]
# An example how the model can be biased in some categories cam be seen by the marriage status.
#
# ```
# ==== SLICE FORF FEATURE : marital-status
# == CLS FOR FEATURE : Never-married
# precision: 0.9513274336283186, recall: 0.4378818737270876, fbeta: 0.599721059972106
# TN, FP, FN, TP: (10181, 11, 276, 215)
# == CLS FOR FEATURE : Married-civ-spouse
# precision: 0.792938459000165, recall: 0.7181709503885236, fbeta: 0.7537050105857446
# TN, FP, FN, TP: (7029, 1255, 1886, 4806)
# == CLS FOR FEATURE : Divorced
# precision: 0.8744186046511628, recall: 0.4060475161987041, fbeta: 0.5545722713864307
# TN, FP, FN, TP: (3953, 27, 275, 188)
# ```
#
# People who are never married get very few False Positives, but even more False Negatives than True Positives. That is, the model tend to assume that never-married people
# earn less than they actually do. That can be seen in a higher precision and lower recall than the overall values.
# The model is accurate when it recognizes when never-married people make more than 50k, but flags incorrectly many never-married people as low-income, when they in reality make more money. That's obviously because most never-married people in the database make little money, and the model may see this as an indication of low income. We see the same phenomen for divorced.
#
# For Married-civ-spouse entries, on the other hand, we do not see this effect. We have even a False Negative rate than the overall average, and a much better recall. The model is more accurate than on the full data-set when it flags a family as low-income, but is not.
# It has a comparable precision as recorded in the full dataset, which means that the model is not as eager as in never-married entries to flag someone as low-income, but may treate this situation as neutral.

# %% [markdown]
# ```
# ==== SLICE FORF FEATURE : sex
# == CLS FOR FEATURE : Male
# precision: 0.8010186160871092, recall: 0.6846292404683278, fbeta: 0.738264810618323
# TN, FP, FN, TP: (13995, 1133, 2101, 4561)
# == CLS FOR FEATURE : Female
# precision: 0.8169642857142857, recall: 0.6208651399491094, fbeta: 0.7055421686746988
# TN, FP, FN, TP: (9428, 164, 447, 732)
# ```
#
# ```
# == CLS FOR FEATURE : White
# precision: 0.8037880046519356, recall: 0.6797808065196009, fbeta: 0.7366017052375152
# TN, FP, FN, TP: (19518, 1181, 2279, 4838)
# == CLS FOR FEATURE : Black
# precision: 0.823943661971831, recall: 0.6046511627906976, fbeta: 0.6974664679582713
# TN, FP, FN, TP: (2687, 50, 153, 234)
# ```
#
#
# As expected we see the same phenomenon in other splits, although it is not as dramatic as one might fear. We see that female have lower recall and are more often incorrectly flagged as low-income than males. So is the case for black people compared to white people.
